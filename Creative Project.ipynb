# %% [markdown]
# #### Hello!
# This is a jupyter notebook. Each of the rectangles that contain information in them is called a cell. To advance through the notebook click on a cell and hit shift + enter in the keyboard simultaneously to run the cell. Try it by first clicking on the cell that contains this text and hit shift + enter. It will run the cell and automatically move down to the next cell.

# %% [markdown]
# #### Good job!
# You just ran the previous cell. Continue through the rest of the jupyter notebook by hitting shift + enter to experience an interactive poem. Different cells will produce different things. If you want to go back to a previous cell and re-run it, no problem, just click the cell you want to run and hit shift + enter.
#
# Text cells like this one and the one before will not produce something like a plot or image, but cells that contain code, like the cell directly below this, may sometimes produce a plot or image depending on what it is they're doing. The cell below this imports different packages that I use to create plots and images, meaning once run it will not produce anything below. The poem starts a few cells after the one below and is marked clearly by the title, "ni mujer ni hombre."
#
# #### Have fun!

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd

from jupyterthemes import jtplot
jtplot.style(grid=False)

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # ni mujer ni hombre
#  ###### neither woman nor man

# %% [markdown]
# ni mujer ni hombre
#
# *neither woman nor man*
#
# existo entre los dos
#
# *I exist between the two*
#
# I am both and I am neither
#
# what does that make me?
#
# ni hombre ni mujer

# %% [markdown]
# neither Mexican nor American
#
# I exist somewhere between the two
#
# in a culture re**brand**ed
#
# re**name**d
#
# re**colonize**d
#
# **Chicanx**

# %%
plt.figure(dpi=100)
img = mpimg.imread('chicanx.png')
imgplot = plt.imshow(img)
plt.xticks([100, 200, 300, 400, 500, 600], 
           ['me','me','me','me','me','me'])
plt.yticks([100, 200, 300, 400], [' ',' ',' ',' ',' '])
plt.show()

# %% [markdown]
# my culture was founded on rape
#
# on genocide
#
# on colonization

# %% [markdown]
# is that why 10 women a day are murdered in Mexico?
#
# is that why children are reprimanded with assault as well as words?
#
# is that why my my mom is so proud of her *Spanish* heritage?
#
# of her father who was from *Spain*
#
# and had blonde hair and blue eyes
#
# whose abandonment of his wife and children is dimmed in the shadow of his origin?
#
# (did I mention he's from ***Spain***??)

# %% [markdown]
# I think that's why we're known as a *good looking* Mexican family
#
# because I'm apparently not too *spicy* for white boys' palettes
#
# even though I've got a *fiery* personality

# %% [markdown]
# my complexion reflects the perfect blend of colonization
#
# which according to 23andMe looks like this:

# %%
labels = ['Native American (Nuevo Leon Region, Mexico)',
          'European',
          'Sub-Saharan African', 
          'Western Asian & North African', 
          'Unidentifiable DNA']
percentages = [27.1, 60.6, 3.0, 1.4, 7.9]
colors = ['olive','maroon','wheat','cadetblue','grey']
fig1, ax1 = plt.subplots()
ax1.pie(percentages, labels=labels, colors=colors, rotatelabels=True)
ax1.axis('equal')
plt.title('Priscilla')
plt.show()

# %% [markdown]
# you're welcome for the family recipe
#
# buen provecho!

# %% [markdown]
# like the history of my DNA is at odds
#
# so thus is my mind
#
# "God says love is meant to exist between a man and a woman"
#
# gracias padre, por la guía
#
# *thank you father, for the guidance*
#
# thank you for the years of homophobic slurs
#
# thank you for the years of feeling like sin incarnate
#
# like the devil's hold on my soul has gotten tighter with every explicit thought, touch, and act I've experienced
#
# thank you for the years of unlearning I've had to do

# %%
plt.figure(dpi=100)
x = np.arange(-20,6,1)
y = np.multiply(1.8,np.ones(len(x)))
xexp = np.arange(-20,-1,0.1)
yexp = [(2*i - 3)/(i +1) for i in xexp]
plt.plot(x, y, 'w', linewidth=2, label='dogma')
plt.plot(xexp, yexp, 'brown', linewidth=2, label='me')
plt.ylim(-10,30)
plt.xlim(-20,5)
plt.yticks((25, 5, -15),(' ',' ',' '))
plt.xticks((-20, -10, 4),(' ',' ',' '))
plt.legend()
plt.show()

# %% [markdown]
# I've committed the most voilent of sins
#
# immoral
#
# unclean
#
# sacreligious
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# . . . *sex*
#
# (no, not **fratricide**, where'd you get that idea?)

# %% [markdown]
# burn me at the stake for my sins
#
# but know that I'll be enjoying it
#
# the fire on my skin as hot as the desire that scorches my body's nerve endings
#
# I *want* to burn alive
#
# **do you want to burn with me?**

# %% [markdown]
# I used to this enjoyment was parasitic
#
# a sickness in my being that could never be sated no matter how much it consumed
#
# turns out it's just me

# %% [markdown]
# me
#
# who doesn't think relationships are synonymous with monogamy
#
# me
#
# who dreamt of your face between my legs last night and woke in a light sheen of sweat
#
# me
#
# who finds moments of peace in the times you're lying next to me
#
# when my face is gently kissed by your breath
#
# and my waist is contoured by the shape of your arm
#
# me
#
# who exists in the space between masculinity and femininity
#
# yo soy
#
# ni hombre ni mujer

# %%
plt.figure(dpi=100)
img = mpimg.imread('me.png')
imgplot = plt.imshow(img)
plt.xticks([100, 350, 600], 
           ['man','where I live','woman'])
plt.yticks([100, 200, 300, 400], [' ',' ',' ',' ',' '])
plt.show()
